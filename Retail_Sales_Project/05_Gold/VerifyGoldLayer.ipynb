# %%
# %sql
SHOW TABLES IN retail_analytics_catalog.gold;

# %% [markdown]
# ###Test Queries

# %% [markdown]
# Top 10 Customers

# %%
# %sql
SELECT *
FROM retail_analytics_catalog.gold.top_customers
ORDER BY rank
LIMIT 10;

# %% [markdown]
# Top Products

# %%
# %sql
SELECT *
FROM retail_analytics_catalog.gold.sales_by_product
ORDER BY total_sales DESC;

# %% [markdown]
# Sales by City

# %%
# %sql
SELECT *
FROM retail_analytics_catalog.gold.sales_by_city
ORDER BY total_sales DESC;

# %% [markdown]
# Monthly Revenue

# %%
# %sql
SELECT *
FROM retail_analytics_catalog.gold.monthly_sales;
